# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import tree
from matplotlib import pyplot as plt

data = pd.read_csv('patient_drug_data.csv')

data.head()
# Out:
#    Patient ID         Age Sex      BP Cholesterol    Drug
# 0           1       Young   F    High      Normal  Drug A
# 1           2       Young   F    High        High  Drug A
# 2           3  Middle-age   F    High      Normal  Drug B
# 3           4      Senior   F  Normal      Normal  Drug B
# 4           5      Senior   M     Low      Normal  Drug B

# %%
data.columns
# Out:
# Index(['Patient ID', 'Age', 'Sex', 'BP', 'Cholesterol', 'Drug'], dtype='object')

# %%
x= data.drop(columns=['Drug']).drop(columns=['Patient ID'])
x = pd.get_dummies(x)
y= data['Drug']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

clf = DecisionTreeClassifier(random_state = 6,max_depth = 5)
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=6)

# %%
fig = plt.figure(figsize=(25,30))
_ = tree.plot_tree(clf, 
                   feature_names=x.columns,  
                   class_names=y.unique(),
                   filled=True)
